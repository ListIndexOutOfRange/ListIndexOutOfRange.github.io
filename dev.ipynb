# %%
import numpy as np
from PIL import Image
from matplotlib import pyplot as plt
from matplotlib.image import imsave
from skimage import img_as_float

# %%
image = img_as_float(np.array(Image.open('content/PFGM/assets/title.png')))[:, :, :3]

# %%
test = 1 - image

# %%
imsave('title_black.png', test)

# %%
plt.imshow(test)
