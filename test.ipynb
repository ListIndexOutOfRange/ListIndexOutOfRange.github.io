# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
image = np.array(Image.open('./static/images/logo_icube.png'))

# %%
image.shape
# Out:
# (1029, 2792, 4)

# %%
plt.imshow(image)
